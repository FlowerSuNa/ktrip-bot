# %%
import os
import requests
import sqlite3

import pandas as pd

from urllib.parse import urlencode, quote
from dotenv import load_dotenv

# %%
load_dotenv()

ENCODING_API_KEY = os.environ["ENCODING_API_KEY"]
DECODING_API_KEY = os.environ["DECODING_API_KEY"]
BASE_URL = "http://apis.data.go.kr/B551011/{lang}Service2/"

DB_NAME = "../kto_data.db"

# %%
def get_data(endpoint:str, params:dict, lang:str="Kor"):
    url = BASE_URL.format(lang=lang) + endpoint + "?"+ urlencode(params)
    print()

    response = requests.get(url) 
    if response.status_code == 200:
        if "SERVICE ERROR" in response.text:
            print(response.text)
            return []
        
        try:
            data = response.json()["response"]["body"]

            if data["totalCount"] > 0:
                return data["items"]["item"]
        except Exception as e:
            print(e)
            print(response.text)
        
        return []
    else:
        print("API 호출 실패:", response.status_code)
        return []

# %%
def insert_into_db(insert_data:list, insert_query:str, create_query:str=None):
    conn = sqlite3.connect(DB_NAME)
    cur = conn.cursor()

    if create_query:
        cur.execute(create_query)

    cur.executemany(insert_query, insert_data)
    conn.commit()
    conn.close()

# %%
def drop_table(table_name:str):
    conn = sqlite3.connect(DB_NAME)
    cur = conn.cursor()
    cur.execute(f"DROP TABLE {table_name}")
    conn.commit()
    conn.close()

# %% [markdown]
# ## 1. 코드 데이터 탐색

# %% [markdown]
# ### 1\) 법정 지역 코드

# %%
endpoint = 'ldongCode2'
params = {
    "numOfRows": 300,
    "MobileOS": "ETC",
    "MobileApp": "ktrip-bot",
    "serviceKey": DECODING_API_KEY,
    "_type": "json",
    "lDongListYn": "Y"
}
lang = "Eng"
data = get_data(endpoint, params, lang)
data[:3]
# Out:
# [{'lDongRegnCd': '11',
#   'lDongRegnNm': 'Seoul',
#   'lDongSignguCd': '110',
#   'lDongSignguNm': 'Jongno-gu',
#   'rnum': 1},
#  {'lDongRegnCd': '11',
#   'lDongRegnNm': 'Seoul',
#   'lDongSignguCd': '140',
#   'lDongSignguNm': 'Jung-gu',
#   'rnum': 2},
#  {'lDongRegnCd': '11',
#   'lDongRegnNm': 'Seoul',
#   'lDongSignguCd': '170',
#   'lDongSignguNm': 'Yongsan-gu',
#   'rnum': 3}]

# %%
# drop_table(endpoint)

# %%
create_query = f"""
CREATE TABLE IF NOT EXISTS {endpoint} (
    lDongRegnCd     VARCHAR(5),
    lDongRegnNm     TEXT,
    lDongSignguCd   VARCHAR(5),
    lDongSignguNm   TEXT,
    lang            VARCHAR(5)
)
"""
insert_query = f"""
INSERT INTO {endpoint} (lDongRegnCd, lDongRegnNm, lDongSignguCd, lDongSignguNm, lang) 
VALUES (:lDongRegnCd, :lDongRegnNm, :lDongSignguCd, :lDongSignguNm, '{lang}')
"""

insert_into_db(data, insert_query, create_query)

# %% [markdown]
# ### 2\) 분류체계 코드

# %%
endpoint = 'lclsSystmCode2'
params = {
    "serviceKey": DECODING_API_KEY,
    "numOfRows": 300,
    "MobileOS": "ETC",
    "MobileApp": "ktrip-bot",
    "_type": "json",
    "lclsSystmListYn": "Y"
}
lang = "Eng"
data = get_data(endpoint, params, lang)
data[:3]
# Out:
# [{'lclsSystm1Cd': 'AC',
#   'lclsSystm1Nm': 'Accommodation',
#   'lclsSystm2Cd': 'AC01',
#   'lclsSystm2Nm': 'Hotels',
#   'lclsSystm3Cd': 'AC010100',
#   'lclsSystm3Nm': 'Hotels',
#   'rnum': 1},
#  {'lclsSystm1Cd': 'AC',
#   'lclsSystm1Nm': 'Accommodation',
#   'lclsSystm2Cd': 'AC02',
#   'lclsSystm2Nm': 'Condominiums',
#   'lclsSystm3Cd': 'AC020100',
#   'lclsSystm3Nm': 'Condominiums',
#   'rnum': 2},
#  {'lclsSystm1Cd': 'AC',
#   'lclsSystm1Nm': 'Accommodation',
#   'lclsSystm2Cd': 'AC02',
#   'lclsSystm2Nm': 'Condominiums',
#   'lclsSystm3Cd': 'AC020200',
#   'lclsSystm3Nm': 'Serviced Residences',
#   'rnum': 3}]

# %%
# drop_table(endpoint)

# %%
create_query = f"""
CREATE TABLE IF NOT EXISTS {endpoint} (
    lclsSystm1Cd   VARCHAR(2),
    lclsSystm1Nm   TEXT,
    lclsSystm2Cd   VARCHAR(4),
    lclsSystm2Nm   TEXT,
    lclsSystm3Cd   VARCHAR(8),
    lclsSystm3Nm   TEXT,
    lang           VARCHAR(5)
)
"""
insert_query = f"""
INSERT INTO {endpoint} 
(lclsSystm1Cd, lclsSystm1Nm, lclsSystm2Cd, lclsSystm2Nm, lclsSystm3Cd, lclsSystm3Nm, lang)
VALUES 
(:lclsSystm1Cd, :lclsSystm1Nm, :lclsSystm2Cd, :lclsSystm2Nm, :lclsSystm3Cd, :lclsSystm3Nm, '{lang}')
"""

insert_into_db(data, insert_query, create_query)

# %% [markdown]
# ## 2. 관광지 데이터 탐색

# %% [markdown]
# ### 1\) 지역별 관광지 검색

# %%
endpoint = 'areaBasedList2'
params = {
    "numOfRows": 3,
    "MobileOS": "ETC",
    "MobileApp": "ktrip-bot",
    "_type": "json",
    "arrange": "C",
    "serviceKey": DECODING_API_KEY,
    "lDongRegnCd": "47",
    # "lclsSystm1": "VE",
    # "lclsSystm2": "VE01",
}
data = get_data(endpoint, params)
data
# Out:
# [{'addr1': '경상북도 경주시 천북면 물천리',
#   'addr2': '944-7',
#   'areacode': '35',
#   'cat1': 'A02',
#   'cat2': 'A0202',
#   'cat3': 'A02020700',
#   'contentid': '3501757',
#   'contenttypeid': '12',
#   'createdtime': '20250701165242',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/21/3501721_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/21/3501721_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.2770278210',
#   'mapy': '35.8688439662',
#   'mlevel': '6',
#   'modifiedtime': '20250701165259',
#   'sigungucode': '2',
#   'tel': '',
#   'title': '경주시 자전거공원',
#   'zipcode': '38038',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'VE',
#   'lclsSystm2': 'VE03',
#   'lclsSystm3': 'VE030500'},
#  {'addr1': '경상북도 의성군 다인면 대곡사길 80',
#   'addr2': '',
#   'areacode': '35',
#   'cat1': 'A02',
#   'cat2': 'A0201',
#   'cat3': 'A02010800',
#   'contentid': '127360',
#   'contenttypeid': '12',
#   'createdtime': '20040226090000',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/10/2690110_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/10/2690110_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.3771312125',
#   'mapy': '36.4901509985',
#   'mlevel': '6',
#   'modifiedtime': '20250701163721',
#   'sigungucode': '19',
#   'tel': '',
#   'title': '대곡사(의성)',
#   'zipcode': '37301',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '730',
#   'lclsSystm1': 'HS',
#   'lclsSystm2': 'HS03',
#   'lclsSystm3': 'HS030100'},
#  {'addr1': '경상북도 영주시 순흥면 소백로 2780',
#   'addr2': '',
#   'areacode': '35',
#   'cat1': 'A02',
#   'cat2': 'A0206',
#   'cat3': 'A02060100',
#   'contentid': '130894',
#   'contenttypeid': '14',
#   'createdtime': '20070216090000',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/63/207663_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/63/207663_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.5820781426',
#   'mapy': '36.9258299838',
#   'mlevel': '6',
#   'modifiedtime': '20250701163225',
#   'sigungucode': '14',
#   'tel': '',
#   'title': '소수박물관',
#   'zipcode': '36013',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '210',
#   'lclsSystm1': 'VE',
#   'lclsSystm2': 'VE07',
#   'lclsSystm3': 'VE070100'}]

# %% [markdown]
# ### 2\) 관광지 키워드 검색

# %%
endpoint = 'searchKeyword2'
params = {
    "numOfRows": 300,
    "MobileOS": "ETC",
    "MobileApp": "ktrip-bot",
    "_type": "json",
    "arrange": "C",
    "keyword": "카페",
    "serviceKey": DECODING_API_KEY,
    "lDongRegnCd": "47",
    # "lclsSystm1": "VE",
    # "lclsSystm2": "VE01",
}
data = get_data(endpoint, params)
data
# Out:
# {"response": {"header":{"resultCode":"0000","resultMsg":"OK"},"body": {"items": {"item":[{"addr1":"경상북도 경주시 동해안로 1488","addr2":"","zipcode":"38123","areacode":"35","cat1":"A05","cat2":"A0502","cat3":"A05020900","contentid":"2905411","contenttypeid":"39","createdtime":"20221110172135","firstimage":"http://tong.visitkorea.or.kr/cms/resource/93/2905393_image2_1.jpg","firstimage2":"http://tong.visitkorea.or.kr/cms/resource/93/2905393_image3_1.jpg","cpyrhtDivCd":"Type3","mapx":"129.4847381802","mapy":"35.7454007193","mlevel":"6","modifiedtime":"20250626155850","sigungucode":"2","tel":"","title":"감포이견대카페","lDongRegnCd":"47","lDongSignguCd":"130","lclsSystm1":"FD","lclsSystm2":"FD05","lclsSystm3":"FD050100"},{"addr1":"경상북도 포항시 북구 동해대로 3290","addr2":"","zipcode":"37510","areacode":"35","cat1":"A05","cat2":"A0502","cat3":"A05020900","contentid":"2842542","contenttypeid":"39","createdtime":"20220824100356","firstimage":"http://tong.visitkorea.or.kr/cms/resource/36/2842536_image2_1.jpg","firstimage2":"http://tong.visitkorea.or.kr/cms/resource/36/2842536_image3_1.jpg","cpyrhtDivCd":"Type3","mapx":"129.3731970643","mapy":"36.2562130793","mlevel":"6","modifiedtime":"20250626150436","sigungucode":"23","tel":"","title":"카페1703","lDongRegnCd":"47","lDongSignguCd":"113","lclsSystm1":"FD","lclsSystm2":"FD05","lclsSystm3":"FD050100"},{"addr1":"경상북도 영천시 화북면 천문로 2118","addr2":"","zipcode":"38813","areacode":"35","cat1":"A03","cat2":"A0302","cat3":"A03021700","contentid":"2752985","contenttypeid":"28","createdtime":"20211005230651","firstimage":"http://tong.visitkorea.or.kr/cms/resource/13/2800213_image2_1.jpg","firstimage2":"http://tong.visitkorea.or.kr/cms/resource/13/2800213_image3_1.jpg","cpyrhtDivCd":"Type3","mapx":"128.9118477385","mapy":"36.1007247321","mlevel":"6","modifiedtime":"20250626142118","sigungucode":"15","tel":"","title":"채송화카페\u0026글램핑","lDongRegnCd":"47","lDongSignguCd":"230","lclsSystm1":"AC","lclsSystm2":"AC05","lclsSystm3":"AC050400"},{"addr1":"경상북도 경산시 압량읍 압독1로 100-5","addr2":"더웨이투커피 외 19개소","zipcode":"38539","areacode":"35","cat1":"A02","cat2":"A0207","cat3":"A02070200","contentid":"3497502","contenttypeid":"15","createdtime":"20250611173452","firstimage":"http://tong.visitkorea.or.kr/cms/resource/85/3497485_image2_1.png","firstimage2":"http://tong.visitkorea.or.kr/cms/resource/85/3497485_image3_1.png","cpyrhtDivCd":"Type3","mapx":"128.7741060914","mapy":"35.8410071265","mlevel":"6","modifiedtime":"20250624150717","sigungucode":"1","tel":"053-819-0332","title":"경산카페축제","lDongRegnCd":"47","lDongSignguCd":"290","lclsSystm1":"EV","lclsSystm2":"EV01","lclsSystm3":"EV010600"},{"addr1":"경상북도 문경시 가은읍 대야로 2441","addr2":"","zipcode":"36996","areacode":"35","cat1":"A05","cat2":"A0502","cat3":"A05020900","contentid":"2717487","contenttypeid":"39","createdtime":"20210518014203","firstimage":"","firstimage2":"","cpyrhtDivCd":"","mapx":"128.0605076890","mapy":"36.6495685887","mlevel":"6","modifiedtime":"20250319132613","sigungucode":"7","tel":"054-571-2441","title":"카페 가은역(문경 구 가은역)","lDongRegnCd":"47","lDongSignguCd":"280","lclsSystm1":"FD","lclsSystm2":"FD05","lclsSystm3":"FD050100"},{"addr1":"경상북도 영덕군 강구면 영덕대게로 192","addr2":"","zipcode":"36453","areacode":"35","cat1":"A05","cat2":"A0502","cat3":"A05020900","contentid":"2605352","contenttypeid":"39","createdtime":"20190606010839","firstimage":"","firstimage2":"","cpyrhtDivCd":"","mapx":"129.3946975004","mapy":"36.3661676819","mlevel":"6","modifiedtime":"20250317132911","sigungucode":"12","tel":"054-734-8189","title":"카페 봄","lDongRegnCd":"47","lDongSignguCd":"770","lclsSystm1":"FD","lclsSystm2":"FD05","lclsSystm3":"FD050100"},{"addr1":"경상북도 영덕군 영해면 예주시장6길 24-1","addr2":"1층","zipcode":"36411","areacode":"35","cat1":"A05","cat2":"A0502","cat3":"A05020900","contentid":"3338783","contenttypeid":"39","createdtime":"20240726152703","firstimage":"http://tong.visitkorea.or.kr/cms/resource/62/3338762_image2_1.jpg","firstimage2":"http://tong.visitkorea.or.kr/cms/resource/62/3338762_image3_1.jpg"," ...
# [{'addr1': '경상북도 경주시 동해안로 1488',
#   'addr2': '',
#   'zipcode': '38123',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2905411',
#   'contenttypeid': '39',
#   'createdtime': '20221110172135',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/93/2905393_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/93/2905393_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.4847381802',
#   'mapy': '35.7454007193',
#   'mlevel': '6',
#   'modifiedtime': '20250626155850',
#   'sigungucode': '2',
#   'tel': '',
#   'title': '감포이견대카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 포항시 북구 동해대로 3290',
#   'addr2': '',
#   'zipcode': '37510',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2842542',
#   'contenttypeid': '39',
#   'createdtime': '20220824100356',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/36/2842536_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/36/2842536_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.3731970643',
#   'mapy': '36.2562130793',
#   'mlevel': '6',
#   'modifiedtime': '20250626150436',
#   'sigungucode': '23',
#   'tel': '',
#   'title': '카페1703',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '113',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 영천시 화북면 천문로 2118',
#   'addr2': '',
#   'zipcode': '38813',
#   'areacode': '35',
#   'cat1': 'A03',
#   'cat2': 'A0302',
#   'cat3': 'A03021700',
#   'contentid': '2752985',
#   'contenttypeid': '28',
#   'createdtime': '20211005230651',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/13/2800213_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/13/2800213_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.9118477385',
#   'mapy': '36.1007247321',
#   'mlevel': '6',
#   'modifiedtime': '20250626142118',
#   'sigungucode': '15',
#   'tel': '',
#   'title': '채송화카페&글램핑',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '230',
#   'lclsSystm1': 'AC',
#   'lclsSystm2': 'AC05',
#   'lclsSystm3': 'AC050400'},
#  {'addr1': '경상북도 경산시 압량읍 압독1로 100-5',
#   'addr2': '더웨이투커피 외 19개소',
#   'zipcode': '38539',
#   'areacode': '35',
#   'cat1': 'A02',
#   'cat2': 'A0207',
#   'cat3': 'A02070200',
#   'contentid': '3497502',
#   'contenttypeid': '15',
#   'createdtime': '20250611173452',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/85/3497485_image2_1.png',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/85/3497485_image3_1.png',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.7741060914',
#   'mapy': '35.8410071265',
#   'mlevel': '6',
#   'modifiedtime': '20250624150717',
#   'sigungucode': '1',
#   'tel': '053-819-0332',
#   'title': '경산카페축제',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '290',
#   'lclsSystm1': 'EV',
#   'lclsSystm2': 'EV01',
#   'lclsSystm3': 'EV010600'},
#  {'addr1': '경상북도 문경시 가은읍 대야로 2441',
#   'addr2': '',
#   'zipcode': '36996',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2717487',
#   'contenttypeid': '39',
#   'createdtime': '20210518014203',
#   'firstimage': '',
#   'firstimage2': '',
#   'cpyrhtDivCd': '',
#   'mapx': '128.0605076890',
#   'mapy': '36.6495685887',
#   'mlevel': '6',
#   'modifiedtime': '20250319132613',
#   'sigungucode': '7',
#   'tel': '054-571-2441',
#   'title': '카페 가은역(문경 구 가은역)',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '280',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 영덕군 강구면 영덕대게로 192',
#   'addr2': '',
#   'zipcode': '36453',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2605352',
#   'contenttypeid': '39',
#   'createdtime': '20190606010839',
#   'firstimage': '',
#   'firstimage2': '',
#   'cpyrhtDivCd': '',
#   'mapx': '129.3946975004',
#   'mapy': '36.3661676819',
#   'mlevel': '6',
#   'modifiedtime': '20250317132911',
#   'sigungucode': '12',
#   'tel': '054-734-8189',
#   'title': '카페 봄',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '770',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 영덕군 영해면 예주시장6길 24-1',
#   'addr2': '1층',
#   'zipcode': '36411',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '3338783',
#   'contenttypeid': '39',
#   'createdtime': '20240726152703',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/62/3338762_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/62/3338762_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.4075884011',
#   'mapy': '36.5415313320',
#   'mlevel': '6',
#   'modifiedtime': '20250314171209',
#   'sigungucode': '12',
#   'tel': '',
#   'title': '동해안카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '770',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 고령군 다산면 좌학길 12',
#   'addr2': '',
#   'zipcode': '40110',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '3472154',
#   'contenttypeid': '39',
#   'createdtime': '20250203133720',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/41/3472141_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/41/3472141_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.4447245518',
#   'mapy': '35.8204283831',
#   'mlevel': '6',
#   'modifiedtime': '20250203133922',
#   'sigungucode': '3',
#   'tel': '',
#   'title': '밤부카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '830',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 영덕군 영덕읍 중앙길 46',
#   'addr2': '1층',
#   'zipcode': '36426',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '3470107',
#   'contenttypeid': '39',
#   'createdtime': '20250123133442',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/85/3470085_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/85/3470085_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.3752784567',
#   'mapy': '36.4106733647',
#   'mlevel': '6',
#   'modifiedtime': '20250123134559',
#   'sigungucode': '12',
#   'tel': '',
#   'title': '카카베이커리카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '770',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 경주시 첨성로81번길 22-7',
#   'addr2': '1층',
#   'zipcode': '38166',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2840787',
#   'contenttypeid': '39',
#   'createdtime': '20220822155824',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/82/2840782_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/82/2840782_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.2119594867',
#   'mapy': '35.8350576614',
#   'mlevel': '6',
#   'modifiedtime': '20250116103240',
#   'sigungucode': '2',
#   'tel': '',
#   'title': '카페 마르쉐',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 경주시 포석로1092번길 62-8',
#   'addr2': '1층',
#   'zipcode': '38166',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2840804',
#   'contenttypeid': '39',
#   'createdtime': '20220822160459',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/94/2840794_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/94/2840794_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.2146148017',
#   'mapy': '35.8353215698',
#   'mlevel': '6',
#   'modifiedtime': '20250115164650',
#   'sigungucode': '2',
#   'tel': '',
#   'title': '카페솔',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 포항시 북구 해안로445번길 20-13',
#   'addr2': 'A동 3층',
#   'zipcode': '37598',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2842571',
#   'contenttypeid': '39',
#   'createdtime': '20220824101356',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/69/2842569_image2_1.png',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/69/2842569_image3_1.png',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.4065272426',
#   'mapy': '36.0732705498',
#   'mlevel': '6',
#   'modifiedtime': '20250113150029',
#   'sigungucode': '23',
#   'tel': '',
#   'title': '카페 티베이',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '113',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 포항시 남구 해맞이로46번길 74-16',
#   'addr2': '',
#   'zipcode': '37928',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2839248',
#   'contenttypeid': '39',
#   'createdtime': '20220818162756',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/33/2839233_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/33/2839233_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.5725101768',
#   'mapy': '36.0640303348',
#   'mlevel': '6',
#   'modifiedtime': '20250113133408',
#   'sigungucode': '23',
#   'tel': '',
#   'title': '더자리카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '111',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 구미시 지주중류4길 15-14',
#   'addr2': '(오태동)',
#   'zipcode': '39354',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2766591',
#   'contenttypeid': '39',
#   'createdtime': '20211102221810',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/78/2766978_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/78/2766978_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.3741041025',
#   'mapy': '36.0814863722',
#   'mlevel': '6',
#   'modifiedtime': '20250103093350',
#   'sigungucode': '4',
#   'tel': '',
#   'title': '카페화담',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '190',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 청송군 파천면 청송로 5865',
#   'addr2': '',
#   'zipcode': '37414',
#   'areacode': '35',
#   'cat1': 'A01',
#   'cat2': 'A0101',
#   'cat3': 'A01010700',
#   'contentid': '2850704',
#   'contenttypeid': '12',
#   'createdtime': '20220907111907',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/68/3450568_image2_1.JPG',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/68/3450568_image3_1.JPG',
#   'cpyrhtDivCd': 'Type1',
#   'mapx': '129.0266154306',
#   'mapy': '36.4842166583',
#   'mlevel': '6',
#   'modifiedtime': '20241218182036',
#   'sigungucode': '21',
#   'tel': '054-870-6459',
#   'title': '산소카페 청송정원',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '750',
#   'lclsSystm1': 'NA',
#   'lclsSystm2': 'NA04',
#   'lclsSystm3': 'NA040700'},
#  {'addr1': '경상북도 경주시 보문로 132-16',
#   'addr2': '(북군동)',
#   'zipcode': '38117',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2717548',
#   'contenttypeid': '39',
#   'createdtime': '20210518201243',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/41/2717541_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/41/2717541_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.2681762810',
#   'mapy': '35.8526484044',
#   'mlevel': '6',
#   'modifiedtime': '20241217114218',
#   'sigungucode': '2',
#   'tel': '',
#   'title': '카페 플라비우스',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 상주시 도남2길 174 (도남동)',
#   'addr2': '',
#   'zipcode': '37242',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2703427',
#   'contenttypeid': '39',
#   'createdtime': '20210111195153',
#   'firstimage': '',
#   'firstimage2': '',
#   'cpyrhtDivCd': '',
#   'mapx': '128.2563737445',
#   'mapy': '36.4466342881',
#   'mlevel': '6',
#   'modifiedtime': '20241204174305',
#   'sigungucode': '9',
#   'tel': '',
#   'title': '경천섬카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '250',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 울릉군 추산길 88-13',
#   'addr2': '',
#   'zipcode': '40207',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2831704',
#   'contenttypeid': '39',
#   'createdtime': '20220803130027',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/93/2831693_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/93/2831693_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '130.8579958733',
#   'mapy': '37.5342749666',
#   'mlevel': '6',
#   'modifiedtime': '20240826104128',
#   'sigungucode': '17',
#   'tel': '',
#   'title': '카페 울라',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '940',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 포항시 남구 상공로257번길 35-3',
#   'addr2': '(송도동)',
#   'zipcode': '37794',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2738029',
#   'contenttypeid': '39',
#   'createdtime': '20210831222738',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/27/2738527_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/27/2738527_image2_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.3765368309',
#   'mapy': '36.0249060024',
#   'mlevel': '6',
#   'modifiedtime': '20240806160100',
#   'sigungucode': '23',
#   'tel': '',
#   'title': '카페라미닥',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '111',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 경주시 포석로1068번길 3',
#   'addr2': '',
#   'zipcode': '38166',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2903556',
#   'contenttypeid': '39',
#   'createdtime': '20221109164130',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/40/2903540_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/40/2903540_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.2099457344',
#   'mapy': '35.8364602425',
#   'mlevel': '6',
#   'modifiedtime': '20240704093426',
#   'sigungucode': '2',
#   'tel': '',
#   'title': '카페능',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 울진군 죽변중앙로 32',
#   'addr2': '',
#   'zipcode': '36316',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2902944',
#   'contenttypeid': '39',
#   'createdtime': '20221109131004',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/39/2902939_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/39/2902939_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.4134586865',
#   'mapy': '37.0503594842',
#   'mlevel': '6',
#   'modifiedtime': '20240627163855',
#   'sigungucode': '18',
#   'tel': '',
#   'title': '르카페말리',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '930',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 김천시 옥산길 12',
#   'addr2': '',
#   'zipcode': '39661',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2902017',
#   'contenttypeid': '39',
#   'createdtime': '20221108163527',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/14/2902014_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/14/2902014_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.1880309818',
#   'mapy': '36.1070300622',
#   'mlevel': '6',
#   'modifiedtime': '20240627134852',
#   'sigungucode': '6',
#   'tel': '',
#   'title': '양조장카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '150',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 성주군 월항로 560',
#   'addr2': '주2동 카페옐롱',
#   'zipcode': '40038',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2932169',
#   'contenttypeid': '39',
#   'createdtime': '20221212092730',
#   'firstimage': '',
#   'firstimage2': '',
#   'cpyrhtDivCd': '',
#   'mapx': '128.3129188350',
#   'mapy': '35.9457701020',
#   'mlevel': '6',
#   'modifiedtime': '20240624102502',
#   'sigungucode': '10',
#   'tel': '',
#   'title': '카페옐롱',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '840',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 포항시 북구 장량로87번길 49',
#   'addr2': '',
#   'zipcode': '37580',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2842529',
#   'contenttypeid': '39',
#   'createdtime': '20220824095844',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/18/2842518_image2_1.png',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/18/2842518_image3_1.png',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.3907115822',
#   'mapy': '36.0864465343',
#   'mlevel': '6',
#   'modifiedtime': '20240620132639',
#   'sigungucode': '23',
#   'tel': '',
#   'title': '카페 브리즈나인',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '113',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 경주시 괘릉길 12',
#   'addr2': '',
#   'zipcode': '38210',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2840749',
#   'contenttypeid': '39',
#   'createdtime': '20220822154458',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/33/2840733_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/33/2840733_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.3140803972',
#   'mapy': '35.7621928103',
#   'mlevel': '6',
#   'modifiedtime': '20240221160212',
#   'sigungucode': '2',
#   'tel': '',
#   'title': '카페괘릉',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 영천시 포은로 452',
#   'addr2': '',
#   'zipcode': '38817',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2841497',
#   'contenttypeid': '39',
#   'createdtime': '20220823113031',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/86/2841486_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/86/2841486_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.9746168195',
#   'mapy': '36.0169242955',
#   'mlevel': '6',
#   'modifiedtime': '20240220164318',
#   'sigungucode': '15',
#   'tel': '',
#   'title': '카페 온당',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '230',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 경주시 오금큰길 332-6',
#   'addr2': '',
#   'zipcode': '38033',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2840403',
#   'contenttypeid': '39',
#   'createdtime': '20220822112118',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/00/2840400_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/00/2840400_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.2832495927',
#   'mapy': '35.9624501768',
#   'mlevel': '6',
#   'modifiedtime': '20240220163636',
#   'sigungucode': '2',
#   'tel': '',
#   'title': '카페 야생화일기',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 경주시 보불로 100',
#   'addr2': '',
#   'zipcode': '38126',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2840767',
#   'contenttypeid': '39',
#   'createdtime': '20220822155114',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/62/2840762_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/62/2840762_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.3138795301',
#   'mapy': '35.7932226414',
#   'mlevel': '6',
#   'modifiedtime': '20240216134024',
#   'sigungucode': '2',
#   'tel': '',
#   'title': '카페 로드100',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 포항시 북구 해안로 1744',
#   'addr2': '2동',
#   'zipcode': '37530',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2842595',
#   'contenttypeid': '39',
#   'createdtime': '20220824101916',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/83/2842583_image2_1.png',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/83/2842583_image3_1.png',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.3978283059',
#   'mapy': '36.1585051800',
#   'mlevel': '6',
#   'modifiedtime': '20240216114033',
#   'sigungucode': '23',
#   'tel': '',
#   'title': '카페포토피아',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '110',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 포항시 남구 하정로172번길 2',
#   'addr2': '',
#   'zipcode': '37938',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2834344',
#   'contenttypeid': '39',
#   'createdtime': '20220809104839',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/34/2834334_image2_1.png',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/34/2834334_image3_1.png',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.5514895569',
#   'mapy': '35.9768342269',
#   'mlevel': '6',
#   'modifiedtime': '20240213131249',
#   'sigungucode': '23',
#   'tel': '',
#   'title': '카페파도',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '110',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 성주군 참별로 1277',
#   'addr2': '',
#   'zipcode': '40065',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2831838',
#   'contenttypeid': '39',
#   'createdtime': '20220803140312',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/24/2831824_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/24/2831824_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.1836131441',
#   'mapy': '35.8611134605',
#   'mlevel': '6',
#   'modifiedtime': '20240206135307',
#   'sigungucode': '10',
#   'tel': '',
#   'title': '카페그날',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '840',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 경산시 화랑로8길 216',
#   'addr2': '',
#   'zipcode': '38540',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2840567',
#   'contenttypeid': '39',
#   'createdtime': '20220822143415',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/62/2840562_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/62/2840562_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.7717204129',
#   'mapy': '35.8330246517',
#   'mlevel': '6',
#   'modifiedtime': '20240119171446',
#   'sigungucode': '1',
#   'tel': '',
#   'title': '카페 월화수',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '290',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 고령군 대가야로 446-44',
#   'addr2': '',
#   'zipcode': '40165',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2831882',
#   'contenttypeid': '39',
#   'createdtime': '20220803143131',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/78/2831878_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/78/2831878_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.2355611259',
#   'mapy': '35.6651143709',
#   'mlevel': '6',
#   'modifiedtime': '20240119101319',
#   'sigungucode': '3',
#   'tel': '',
#   'title': '카페스톤',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '830',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 성주군 주산로 454',
#   'addr2': '',
#   'zipcode': '40039',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2832079',
#   'contenttypeid': '39',
#   'createdtime': '20220803164509',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/70/2832070_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/70/2832070_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.3229816979',
#   'mapy': '35.9506947270',
#   'mlevel': '6',
#   'modifiedtime': '20240119094236',
#   'sigungucode': '10',
#   'tel': '',
#   'title': '카페 트리팔렛',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '840',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 경주시 해변공원길 4',
#   'addr2': '',
#   'zipcode': '38220',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2840301',
#   'contenttypeid': '39',
#   'createdtime': '20220822101705',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/00/2840300_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/00/2840300_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.4648476537',
#   'mapy': '35.6690617128',
#   'mlevel': '6',
#   'modifiedtime': '20240117151208',
#   'sigungucode': '2',
#   'tel': '',
#   'title': '이스트앵글 베이커리카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 경산시 유곡길 183-29',
#   'addr2': '',
#   'zipcode': '38578',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2840578',
#   'contenttypeid': '39',
#   'createdtime': '20220822143928',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/75/2840575_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/75/2840575_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.7830122942',
#   'mapy': '35.7898436313',
#   'mlevel': '6',
#   'modifiedtime': '20240116164908',
#   'sigungucode': '1',
#   'tel': '',
#   'title': '카페 산토리니 마을',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '290',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 포항시 남구 동해안로 3952-44',
#   'addr2': '',
#   'zipcode': '37943',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2842560',
#   'contenttypeid': '39',
#   'createdtime': '20220824100858',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/53/2842553_image2_1.png',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/53/2842553_image3_1.png',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.5178633945',
#   'mapy': '35.9268308943',
#   'mlevel': '6',
#   'modifiedtime': '20240116164305',
#   'sigungucode': '23',
#   'tel': '',
#   'title': '카페더헤이븐',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '110',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 안동시 안교1길 9',
#   'addr2': '',
#   'zipcode': '36621',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2841268',
#   'contenttypeid': '39',
#   'createdtime': '20220823100943',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/52/2841252_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/52/2841252_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.5739222597',
#   'mapy': '36.5797194396',
#   'mlevel': '6',
#   'modifiedtime': '20240116160941',
#   'sigungucode': '11',
#   'tel': '',
#   'title': '풍전브런치카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '170',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 안동시 경동로 2214',
#   'addr2': '',
#   'zipcode': '36732',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2841380',
#   'contenttypeid': '39',
#   'createdtime': '20220823103943',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/64/2841364_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/64/2841364_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.8768019850',
#   'mapy': '36.5430571084',
#   'mlevel': '6',
#   'modifiedtime': '20240116152248',
#   'sigungucode': '11',
#   'tel': '',
#   'title': '카페뒤뜰',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '170',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 경산시 경안로73길 20',
#   'addr2': '',
#   'zipcode': '38500',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2840067',
#   'contenttypeid': '39',
#   'createdtime': '20220819161415',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/60/2840060_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/60/2840060_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.7307293764',
#   'mapy': '35.8400842042',
#   'mlevel': '6',
#   'modifiedtime': '20240116142558',
#   'sigungucode': '1',
#   'tel': '',
#   'title': '카페 마고포레스트',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '290',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 영주시 신재로 685',
#   'addr2': '',
#   'zipcode': '36050',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020200',
#   'contentid': '2832249',
#   'contenttypeid': '39',
#   'createdtime': '20220804100417',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/32/2832232_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/32/2832232_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.5444836035',
#   'mapy': '36.8538569698',
#   'mlevel': '6',
#   'modifiedtime': '20240109132653',
#   'sigungucode': '14',
#   'tel': '',
#   'title': '카페, 선비꽃',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '210',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD02',
#   'lclsSystm3': 'FD020300'},
#  {'addr1': '경상북도 문경시 영신로 101',
#   'addr2': '1, 2층',
#   'zipcode': '36944',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2832373',
#   'contenttypeid': '39',
#   'createdtime': '20220804105246',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/62/2832362_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/62/2832362_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.2100459541',
#   'mapy': '36.5927361825',
#   'mlevel': '6',
#   'modifiedtime': '20240109112438',
#   'sigungucode': '7',
#   'tel': '',
#   'title': '카페라밀',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '280',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 울릉군 추산길 137',
#   'addr2': '1층',
#   'zipcode': '40208',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020200',
#   'contentid': '2831723',
#   'contenttypeid': '39',
#   'createdtime': '20220803131020',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/06/2831706_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/06/2831706_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '130.8571682361',
#   'mapy': '37.5322279618',
#   'mlevel': '6',
#   'modifiedtime': '20240109093516',
#   'sigungucode': '17',
#   'tel': '',
#   'title': '케렌시아 카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '940',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD02',
#   'lclsSystm3': 'FD020300'},
#  {'addr1': '경상북도 상주시 자산길 28-24',
#   'addr2': '',
#   'zipcode': '37161',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2831784',
#   'contenttypeid': '39',
#   'createdtime': '20220803133738',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/68/2831768_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/68/2831768_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.1486145351',
#   'mapy': '36.4237376976',
#   'mlevel': '6',
#   'modifiedtime': '20240108170126',
#   'sigungucode': '9',
#   'tel': '',
#   'title': '카페둥시',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '250',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 경주시 용담로104번길 13-4',
#   'addr2': '',
#   'zipcode': '38082',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'contentid': '2820735',
#   'contenttypeid': '39',
#   'createdtime': '20220519152702',
#   'firstimage': '',
#   'firstimage2': '',
#   'cpyrhtDivCd': '',
#   'mapx': '129.2110225850',
#   'mapy': '35.8656680763',
#   'mlevel': '6',
#   'modifiedtime': '20240105104613',
#   'sigungucode': '2',
#   'tel': '',
#   'title': '오스카스카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100'},
#  {'addr1': '경상북도 성주군 칠봉2길 36-16 청천서원',
#   'addr2': '',
#   'zipcode': '40055',
#   'areacode': '35',
#   'cat1': 'A02',
#   'cat2': 'A0203',
#   'cat3': 'A02030400',
#   'contentid': '2997257',
#   'contenttypeid': '12',
#   'createdtime': '20230807142606',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/06/2988606_image2_1.JPG',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/06/2988606_image3_1.JPG',
#   'cpyrhtDivCd': 'Type1',
#   'mapx': '128.2301551928',
#   'mapy': '35.8997765880',
#   'mlevel': '6',
#   'modifiedtime': '20231024133933',
#   'sigungucode': '10',
#   'tel': '',
#   'title': '한옥카페 청천',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '840',
#   'lclsSystm1': 'EX',
#   'lclsSystm2': 'EX07',
#   'lclsSystm3': 'EX070200'},
#  {'addr1': '경상북도 안동시 강남로 277',
#   'addr2': '',
#   'zipcode': '36748',
#   'areacode': '35',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020100',
#   'contentid': '2679142',
#   'contenttypeid': '39',
#   'createdtime': '20201028013025',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/35/2677135_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/35/2677135_image2_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '128.7318006526',
#   'mapy': '36.5536642697',
#   'mlevel': '6',
#   'modifiedtime': '20210525195819',
#   'sigungucode': '11',
#   'tel': '054-859-7930',
#   'title': '돈까스카페',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '170',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD01',
#   'lclsSystm3': 'FD010100'}]

# %% [markdown]
# ### 3\) 행사 정보 조회

# %%
endpoint = 'searchFestival2'
params = {
    "numOfRows": 3,
    "MobileOS": "ETC",
    "MobileApp": "ktrip-bot",
    "_type": "json",
    "arrange": "C",
    "eventStartDate": "20250701",
    "serviceKey": DECODING_API_KEY,
    "lDongRegnCd": "47"
}
data = get_data(endpoint, params)
data

# %% [markdown]
# ### 4\) 숙박 정보 조회

# %%
endpoint = 'searchStay2'
params = {
    "numOfRows": 3,
    "MobileOS": "ETC",
    "MobileApp": "ktrip-bot",
    "_type": "json",
    "arrange": "C",
    "serviceKey": DECODING_API_KEY,
    "lDongRegnCd": "47"
}
data = get_data(endpoint, params)
data
# Out:
# [{'addr1': '경상북도 경주시 태종로699번길 31',
#   'addr2': '',
#   'areacode': '35',
#   'sigungucode': '2',
#   'cat1': 'B02',
#   'cat2': 'B0201',
#   'cat3': 'B02011100',
#   'contentid': '2950401',
#   'contenttypeid': '32',
#   'createdtime': '20230217160233',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/10/2949210_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/10/2949210_image3_1.jpg',
#   'cpyrhtDivCd': 'Type1',
#   'mapx': '129.2046571650',
#   'mapy': '35.8415095729',
#   'mlevel': '6',
#   'modifiedtime': '20250626162555',
#   'tel': '',
#   'title': '블라우[한국관광 품질인증/Korea Quality]',
#   'zipcode': '38157',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'AC',
#   'lclsSystm2': 'AC06',
#   'lclsSystm3': 'AC060200'},
#  {'addr1': '경상북도 경주시 국당2길 12-17',
#   'addr2': '',
#   'areacode': '35',
#   'sigungucode': '2',
#   'cat1': 'B02',
#   'cat2': 'B0201',
#   'cat3': 'B02011600',
#   'contentid': '2706608',
#   'contenttypeid': '32',
#   'createdtime': '20210219201904',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/35/2706135_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/35/2706135_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'mapx': '129.2074990288',
#   'mapy': '35.8258280631',
#   'mlevel': '6',
#   'modifiedtime': '20250626112807',
#   'tel': '010-8858-3183, 카카오톡(orung2)',
#   'title': '경주오릉한옥',
#   'zipcode': '38169',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'AC',
#   'lclsSystm2': 'AC03',
#   'lclsSystm3': 'AC030200'},
#  {'addr1': '경상북도 안동시 서후면 태장죽헌길 24',
#   'addr2': '',
#   'areacode': '35',
#   'sigungucode': '11',
#   'cat1': 'B02',
#   'cat2': 'B0201',
#   'cat3': 'B02011600',
#   'contentid': '2637740',
#   'contenttypeid': '32',
#   'createdtime': '20191120190622',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/33/2993133_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/33/2993133_image3_1.jpg',
#   'cpyrhtDivCd': 'Type1',
#   'mapx': '128.6634512323',
#   'mapy': '36.6473772816',
#   'mlevel': '',
#   'modifiedtime': '20250626112004',
#   'tel': '010-5217-2174',
#   'title': '죽헌고택 [한국관광 품질인증/Korea Quality]',
#   'zipcode': '36616',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '170',
#   'lclsSystm1': 'AC',
#   'lclsSystm2': 'AC03',
#   'lclsSystm3': 'AC030200'}]

# %% [markdown]
# ### 5\) 관광지 Overview 조회

# %%
endpoint = 'detailCommon2'
params = {
    "MobileOS": "ETC",
    "MobileApp": "ktrip-bot",
    "_type": "json",
    "contentId": "2905411",
    "numOfRows": 1,
    "serviceKey": DECODING_API_KEY,
}
data = get_data(endpoint, params)
data
# Out:
# [{'contentid': '2905411',
#   'contenttypeid': '39',
#   'title': '감포이견대카페',
#   'createdtime': '20221110172135',
#   'modifiedtime': '20250626155850',
#   'tel': '',
#   'telname': '',
#   'homepage': '',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/93/2905393_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/93/2905393_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'areacode': '35',
#   'sigungucode': '2',
#   'lDongRegnCd': '47',
#   'lDongSignguCd': '130',
#   'lclsSystm1': 'FD',
#   'lclsSystm2': 'FD05',
#   'lclsSystm3': 'FD050100',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020900',
#   'addr1': '경상북도 경주시 동해안로 1488',
#   'addr2': '',
#   'zipcode': '38123',
#   'mapx': '129.4847381802',
#   'mapy': '35.7454007193',
#   'mlevel': '6',
#   'overview': '감포이견대카페는 경상북도 경주시 감포읍 대본리에 있다. 이국적인 멋을 풍기는 외관과 고급스러운 분위기를 연출하는 인테리어가 눈에 띈다. 내부에는 단체석이 마련되어 있어 각종 모임을 하기 좋다. 대표 메뉴는 티라미수다. 이 밖에 아보카도 크림라떼, 아보카 스무디, 아메리카노, 카페라떼, 콜드브루 등 여러 가지 음료가 준비되어 있다. 동경주 IC에서 가깝고, 주변에 경주문무대왕릉과 나정고운모래해변이 있다.'}]

# %% [markdown]
# ### 6\) 관광지 메뉴, 주차, 오픈 시간 등 조회

# %%
endpoint = 'detailIntro2'
params = {
    "MobileOS": "ETC",
    "MobileApp": "ktrip-bot",
    "_type": "json",
    "contentId": "2905411",
    "contentTypeId": "39",
    "numOfRows": 1,
    "serviceKey": DECODING_API_KEY,
}
data = get_data(endpoint, params)
data
# Out:
# [{'contentid': '2905411',
#   'contenttypeid': '39',
#   'seat': '',
#   'kidsfacility': '0',
#   'firstmenu': '티라미수',
#   'treatmenu': '아보카도 크림라떼, 아메리카노, 카페라떼, 콜드브루 등',
#   'smoking': '',
#   'packing': '가능',
#   'infocenterfood': '054-777-1333',
#   'scalefood': '',
#   'parkingfood': '있음(무료)',
#   'opendatefood': '',
#   'opentimefood': '09:00~21:00 (동절기 10:00~20:30)',
#   'restdatefood': '연중무휴',
#   'discountinfofood': '',
#   'chkcreditcardfood': '가능',
#   'reservationfood': '가능',
#   'lcnsno': '20210542876'}]

# %%
endpoint = 'detailInfo2'
params = {
    "MobileOS": "ETC",
    "MobileApp": "ktrip-bot",
    "_type": "json",
    "contentId": "2905411",
    "contentTypeId": "39",
    "numOfRows": 1,
    "serviceKey": DECODING_API_KEY,
}
data = get_data(endpoint, params)
data
# Out:
# [{'contentid': '2905411',
#   'contenttypeid': '39',
#   'serialnum': '0',
#   'infoname': '화장실',
#   'infotext': '있음',
#   'fldgubun': '1'}]

# %%
endpoint = 'detailImage2'
params = {
    "MobileOS": "ETC",
    "MobileApp": "ktrip-bot",
    "_type": "json",
    "contentId": "2905411",
    "imageYN": "Y",
    "numOfRows": 10,
    "serviceKey": DECODING_API_KEY,
}
data = get_data(endpoint, params)
data
# Out:
# [{'contentid': '2905411',
#   'originimgurl': 'http://tong.visitkorea.or.kr/cms/resource/94/2905394_image2_1.jpg',
#   'imgname': '경북_경주시_감포이견대카페_음식_1',
#   'smallimageurl': 'http://tong.visitkorea.or.kr/cms/resource/94/2905394_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'serialnum': '2905394_2'},
#  {'contentid': '2905411',
#   'originimgurl': 'http://tong.visitkorea.or.kr/cms/resource/95/2905395_image2_1.jpg',
#   'imgname': '경북_경주시_감포이견대카페_음식_2',
#   'smallimageurl': 'http://tong.visitkorea.or.kr/cms/resource/95/2905395_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'serialnum': '2905395_4'},
#  {'contentid': '2905411',
#   'originimgurl': 'http://tong.visitkorea.or.kr/cms/resource/96/2905396_image2_1.jpg',
#   'imgname': '경북_경주시_감포이견대카페_음식_3',
#   'smallimageurl': 'http://tong.visitkorea.or.kr/cms/resource/96/2905396_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'serialnum': '2905396_1'},
#  {'contentid': '2905411',
#   'originimgurl': 'http://tong.visitkorea.or.kr/cms/resource/97/2905397_image2_1.jpg',
#   'imgname': '경북_경주시_감포이견대카페_음식_4',
#   'smallimageurl': 'http://tong.visitkorea.or.kr/cms/resource/97/2905397_image3_1.jpg',
#   'cpyrhtDivCd': 'Type3',
#   'serialnum': '2905397_3'}]
